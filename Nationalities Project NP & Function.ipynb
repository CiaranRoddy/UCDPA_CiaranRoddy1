# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter

# %%
df=pd.read_csv("EPL_20_21.csv")

# %%
df
# Out:
#                   Name              Club Nationality Position  Age  Matches  \
# 0          Mason Mount           Chelsea         ENG    MF,FW   21       36
# 1        Edouard Mendy           Chelsea         SEN       GK   28       31
# 2          Timo Werner           Chelsea         GER       FW   24       35
# 3         Ben Chilwell           Chelsea         ENG       DF   23       27
# 4          Reece James           Chelsea         ENG       DF   20       32
# ..                 ...               ...         ...      ...  ...      ...
# 527        Lys Mousset  Sheffield United         FRA    FW,MF   24       11
# 528     Jack O'Connell  Sheffield United         ENG       DF   26        2
# 529      Iliman Ndiaye  Sheffield United         FRA       MF   21        1
# 530  Antwoine Hackford  Sheffield United         ENG    DF,FW   16        1
# 531        Femi Seriki  Sheffield United         ENG       DF   17        1
#
# ...

# %%
# Dictionary used for Nationalies to get the 20 most common in the EPL


nationality_dict = dict(Counter(df['Nationality']).most_common(20))
plt.bar(nationality_dict.keys(), nationality_dict.values(), color=["r","b","yellow","coral","r","g","steelblue","orange","r","r","w","skyblue","palegreen","g","w","r","r","g","b","yellow"], edgecolor= "black")

plt.xlabel('Nationality')
plt.grid(True, color = "grey", linewidth = "0.3", linestyle = "-.")
plt.ylabel('Frequency')
plt.title('Bar Plot of Twenty Most Common Nationalities')

plt.xticks(rotation=90)

plt.show()

# %%
# Function made to get non english players playijg within the league


z = df[df["Nationality"]!="ENG"]



def fun (x):
    for i in range (len(x)):
        print(x, "Foreign Players in Premier League")

# %%
fun(z)
# Out:
#                   Name              Club Nationality Position  Age  Matches  \
# 1        Edouard Mendy           Chelsea         SEN       GK   28       31
# 2          Timo Werner           Chelsea         GER       FW   24       35
# 5    César Azpilicueta           Chelsea         ESP       DF   30       26
# 6         N'Golo Kanté           Chelsea         FRA       MF   29       30
# 7             Jorginho           Chelsea         ITA       MF   28       28
# ..                 ...               ...         ...      ...  ...      ...
# 516       Oliver Burke  Sheffield United         SCO       FW   23       25
# 517       Sander Berge  Sheffield United         NOR       MF   22       15
# 518    Oliver McBurnie  Sheffield United         SCO       FW   24       23
# 527        Lys Mousset  Sheffield United         FRA    FW,MF   24       11
# 529      Iliman Ndiaye  Sheffield United         FRA       MF   21        1
#
# ...

# %%
#variable made with np.array to get tyhe exact number of foreign players


np_foreign_players = np.array(z)
np_foreign_players.shape
# Out:
# (340, 18)
