# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df=pd.read_csv("EPL_20_21.csv")

# %%
df
# Out:
#                   Name              Club Nationality Position  Age  Matches  \
# 0          Mason Mount           Chelsea         ENG    MF,FW   21       36
# 1        Edouard Mendy           Chelsea         SEN       GK   28       31
# 2          Timo Werner           Chelsea         GER       FW   24       35
# 3         Ben Chilwell           Chelsea         ENG       DF   23       27
# 4          Reece James           Chelsea         ENG       DF   20       32
# ..                 ...               ...         ...      ...  ...      ...
# 527        Lys Mousset  Sheffield United         FRA    FW,MF   24       11
# 528     Jack O'Connell  Sheffield United         ENG       DF   26        2
# 529      Iliman Ndiaye  Sheffield United         FRA       MF   21        1
# 530  Antwoine Hackford  Sheffield United         ENG    DF,FW   16        1
# 531        Femi Seriki  Sheffield United         ENG       DF   17        1
#
# ...

# %%
df.isna().sum()   # there is no null values present in the Data set
# Out:
# Name                     0
# Club                     0
# Nationality              0
# Position                 0
# Age                      0
# Matches                  0
# Starts                   0
# Mins                     0
# Goals                    0
# Assists                  0
# Passes_Attempted         0
# Perc_Passes_Completed    0
# Penalty_Goals            0
# Penalty_Attempted        0
# xG                       0
# xA                       0
# Yellow_Cards             0
# Red_Cards                0
# dtype: int64

# %%
df.Name.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 527    False
# 528    False
# 529    False
# 530    False
# 531    False
# Name: Name, Length: 532, dtype: bool

# %%
df.Name.duplicated().sum()
# Out:
# 8

# %%
df[df['Name'].duplicated()].head(8)   # from analysing the Name column, 8 duplicates have been discovered, which have been removed
# Out:
#                        Name                  Club Nationality Position  Age  \
# 274            Ross Barkley           Aston Villa         ENG       MF   26
# 307             Joe Willock      Newcastle United         ENG       MF   20
# 376            Theo Walcott           Southampton         ENG    MF,FW   31
# 381         Takumi Minamino           Southampton         JPN    MF,FW   25
# 409             Mathew Ryan              Brighton         AUS       GK   28
# 457      Ruben Loftus-Cheek                Fulham         ENG    MF,FW   24
# 489  Ainsley Maitland-Niles  West Bromwich Albion         ENG       MF   22
# 494        Robert Snodgrass  West Bromwich Albion         SCO    MF,FW   32
#
#      Matches  Starts  Mins  Goals  Assists  Passes_Attempted  \
# 274       24      18  1531      3        1               764
# 307       14      11   978      8        0               235
# 376       21      20  1618      3        3               424
# ...

# %%
df1=df['Name'].drop_duplicates()

# %%
df1
# Out:
# 0            Mason Mount
# 1          Edouard Mendy
# 2            Timo Werner
# 3           Ben Chilwell
# 4            Reece James
#              ...
# 527          Lys Mousset
# 528       Jack O'Connell
# 529        Iliman Ndiaye
# 530    Antwoine Hackford
# 531          Femi Seriki
# Name: Name, Length: 524, dtype: object
