# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("EPL_20_21.csv")

# %%
df
# Out:
#                   Name              Club Nationality Position  Age  Matches  \
# 0          Mason Mount           Chelsea         ENG    MF,FW   21       36
# 1        Edouard Mendy           Chelsea         SEN       GK   28       31
# 2          Timo Werner           Chelsea         GER       FW   24       35
# 3         Ben Chilwell           Chelsea         ENG       DF   23       27
# 4          Reece James           Chelsea         ENG       DF   20       32
# ..                 ...               ...         ...      ...  ...      ...
# 527        Lys Mousset  Sheffield United         FRA    FW,MF   24       11
# 528     Jack O'Connell  Sheffield United         ENG       DF   26        2
# 529      Iliman Ndiaye  Sheffield United         FRA       MF   21        1
# 530  Antwoine Hackford  Sheffield United         ENG    DF,FW   16        1
# 531        Femi Seriki  Sheffield United         ENG       DF   17        1
#
# ...

# %%
br=df[(df["Nationality"]=="BRA")]

# %%
br
# Out:
#                      Name                     Club Nationality Position  Age  \
# 8            Thiago Silva                  Chelsea         BRA       DF   35
# 27                Ederson          Manchester City         BRA       GK   26
# 36          Gabriel Jesus          Manchester City         BRA       FW   23
# 43            Fernandinho          Manchester City         BRA       MF   35
# 57                   Fred        Manchester United         BRA       MF   27
# 68            Alex Telles        Manchester United         BRA       DF   27
# 84                Alisson             Liverpool FC         BRA       GK   27
# 85        Roberto Firmino             Liverpool FC         BRA       FW   28
# 87                Fabinho             Liverpool FC         BRA    DF,MF   26
# 158       Felipe Anderson          West Ham United         BRA    FW,MF   27
# 170           Lucas Moura        Tottenham Hotspur         BRA    FW,MF   27
# ...

# %%
it=df[(df["Nationality"]=="ITA")]

# %%
it
# Out:
#                  Name                     Club Nationality Position  Age  \
# 7            Jorginho                  Chelsea         ITA       MF   28
# 24   Emerson Palmieri                  Chelsea         ITA       DF   25
# 142    Angelo Ogbonna          West Ham United         ITA       DF   32
# 260        Moise Kean                  Everton         ITA       FW   20
# 339   Patrick Cutrone  Wolverhampton Wanderers         ITA    FW,MF   22
#
#      Matches  Starts  Mins  Goals  Assists  Passes_Attempted  \
# 7         28      23  2010      7        1              1739
# 24         2       0    90      0        0                63
# 142       28      28  2492      3        0               960
# 260        2       0    15      0        0                 9
# 339        2       0    25      0        0                 5
#
#      Perc_Passes_Completed  Penalty_Goals  Penalty_Attempted    xG    xA  \
# 7                     89.5              7                  9  0.31  0.09
# ...

# %%
itb=pd.merge(it,br, left_index=True, right_on="Goals").head()

# %%
itb
# Out:
#      Goals    Name_x   Club_x Nationality_x Position_x  Age_x  Matches_x  \
# 236      7  Jorginho  Chelsea           ITA         MF     28         28
#
#      Starts_x  Mins_x  Goals_x  ...  Goals_y  Assists_y  Passes_Attempted_y  \
# 236        23    2010        7  ...        7          3                 772
#
#      Perc_Passes_Completed_y  Penalty_Goals_y  Penalty_Attempted_y  xG_y  \
# 236                     69.2                1                    1  0.36
#
#      xA_y  Yellow_Cards_y Red_Cards_y
# 236   0.1               4           1
#
# [1 rows x 37 columns]

# %%
df_cols = ['Club','Position']
