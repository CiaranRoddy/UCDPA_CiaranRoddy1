# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("EPL_20_21.csv")

# %%
df
# Out:
#                   Name              Club Nationality Position  Age  Matches  \
# 0          Mason Mount           Chelsea         ENG    MF,FW   21       36
# 1        Edouard Mendy           Chelsea         SEN       GK   28       31
# 2          Timo Werner           Chelsea         GER       FW   24       35
# 3         Ben Chilwell           Chelsea         ENG       DF   23       27
# 4          Reece James           Chelsea         ENG       DF   20       32
# ..                 ...               ...         ...      ...  ...      ...
# 527        Lys Mousset  Sheffield United         FRA    FW,MF   24       11
# 528     Jack O'Connell  Sheffield United         ENG       DF   26        2
# 529      Iliman Ndiaye  Sheffield United         FRA       MF   21        1
# 530  Antwoine Hackford  Sheffield United         ENG    DF,FW   16        1
# 531        Femi Seriki  Sheffield United         ENG       DF   17        1
#
# ...

# %%
# Filtering young players by under the age of 24 & adding column of actual goals Per Game with iterrows

yg=df[(df["Age"]<24)&(df["Goals"]>1)] 
for ind,row in yg.iterrows():
    yg.loc[ind,"Actual_Goals_Per_Game"] = row['Goals'] / row['Matches']
# Out:
# C:\Users\croddy\Anaconda3\lib\site-packages\pandas\core\indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# C:\Users\croddy\Anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
yg.head()
# Out:
#                  Name     Club Nationality Position  Age  Matches  Starts  \
# 0         Mason Mount  Chelsea         ENG    MF,FW   21       36      32
# 3        Ben Chilwell  Chelsea         ENG       DF   23       27      27
# 12  Christian Pulisic  Chelsea         USA    FW,MF   21       27      18
# 13        Kai Havertz  Chelsea         GER    MF,FW   21       27      18
# 16      Tammy Abraham  Chelsea         ENG       FW   22       22      12
#
#     Mins  Goals  Assists  Passes_Attempted  Perc_Passes_Completed  \
# 0   2890      6        5              1881                   82.3
# 3   2286      3        5              1806                   78.6
# 12  1738      4        2               690                   80.0
# 13  1520      4        3               765                   86.1
# 16  1040      6        1               218                   68.3
#
#     Penalty_Goals  Penalty_Attempted    xG    xA  Yellow_Cards  Red_Cards  \
# ...

# %%
#Analsying the young players Goals Data from Top to Bottom
# 
yg.sort_values(by="Goals",ascending=False)
# Out:
#                        Name                     Club Nationality Position  \
# 237   Dominic Calvert-Lewin                  Everton         ENG       FW
# 120       Kelechi Iheanacho           Leicester City         NGA       FW
# 54          Marcus Rashford        Manchester United         ENG       FW
# 117           Harvey Barnes           Leicester City         ENG    FW,MF
# 36            Gabriel Jesus          Manchester City         BRA       FW
# 39               Phil Foden          Manchester City         ENG    FW,MF
# 92               Diogo Jota             Liverpool FC         POR       FW
# 307             Joe Willock         Newcastle United         ENG       MF
# 141            Jarrod Bowen          West Ham United         ENG    FW,MF
# 400             Neal Maupay                 Brighton         FRA    FW,MF
# 216           Jack Harrison             Leeds United         ENG       MF
# 115          James Maddison           Leicester City         ENG    MF,FW
# ...

# %%
# Comparing the Actual v Expected Goals Data on Scatter Graph



x=yg["xG"]
y=yg["Actual_Goals_Per_Game"]


plt.scatter(x, y, s=100,alpha=0.35 ,edgecolor ='black', linewidth =1)


plt.ylabel('Expected Goals')

plt.xlabel('Actual Goals')


cbar=plt.colorbar()
cbar.set_label

plt.grid(color = 'grey', linestyle = '--', linewidth = 0.5)

plt.show()

# %%
yg[0:20]
# Out:
#                        Name               Club Nationality Position  Age  \
# 0               Mason Mount            Chelsea         ENG    MF,FW   21
# 3              Ben Chilwell            Chelsea         ENG       DF   23
# 12        Christian Pulisic            Chelsea         USA    FW,MF   21
# 13              Kai Havertz            Chelsea         GER    MF,FW   21
# 16            Tammy Abraham            Chelsea         ENG       FW   22
# 18       Callum Hudson-Odoi            Chelsea         ENG    FW,DF   19
# 36            Gabriel Jesus    Manchester City         BRA       FW   23
# 39               Phil Foden    Manchester City         ENG    FW,MF   20
# 41            Ferrán Torres    Manchester City         ESP    FW,MF   20
# 52        Aaron Wan-Bissaka  Manchester United         ENG       DF   22
# 54          Marcus Rashford  Manchester United         ENG       FW   22
# 59          Scott McTominay  Manchester United         SCO       MF   23
# ...

# %%
xg=yg.loc[:,["Name","xG","Actual_Goals_Per_Game",]]

# %%
u24=np.array(yg)

# %%
u24
# Out:
# array([['Mason Mount', 'Chelsea', 'ENG', 'MF,FW', 21, 36, 32, 2890, 6, 5,
#         1881, 82.3, 1, 1, 0.21, 0.24, 2, 0, 0.16666666666666666],
#        ['Ben Chilwell', 'Chelsea', 'ENG', 'DF', 23, 27, 27, 2286, 3, 5,
#         1806, 78.6, 0, 0, 0.1, 0.11, 3, 0, 0.1111111111111111],
#        ['Christian Pulisic', 'Chelsea', 'USA', 'FW,MF', 21, 27, 18, 1738,
#         4, 2, 690, 80.0, 0, 0, 0.28, 0.14, 2, 0, 0.14814814814814814],
#        ['Kai Havertz', 'Chelsea', 'GER', 'MF,FW', 21, 27, 18, 1520, 4, 3,
#         765, 86.1, 0, 0, 0.37, 0.09, 2, 0, 0.14814814814814814],
#        ['Tammy Abraham', 'Chelsea', 'ENG', 'FW', 22, 22, 12, 1040, 6, 1,
#         218, 68.3, 0, 0, 0.56, 0.07, 0, 0, 0.2727272727272727],
#        ['Callum Hudson-Odoi', 'Chelsea', 'ENG', 'FW,DF', 19, 23, 10,
#         1059, 2, 3, 659, 82.2, 0, 0, 0.12, 0.26, 0, 0,
#         0.08695652173913043],
#        ['Gabriel Jesus', 'Manchester City', 'BRA', 'FW', 23, 29, 22,
# ...

# %%
u24.shape
# Out:
# (51, 19)

# %%
xg
# Out:
#                        Name    xG  Actual_Goals_Per_Game
# 0               Mason Mount  0.21               0.166667
# 3              Ben Chilwell  0.10               0.111111
# 12        Christian Pulisic  0.28               0.148148
# 13              Kai Havertz  0.37               0.148148
# 16            Tammy Abraham  0.56               0.272727
# 18       Callum Hudson-Odoi  0.12               0.086957
# 36            Gabriel Jesus  0.38               0.310345
# 39               Phil Foden  0.31               0.321429
# 41            Ferrán Torres  0.37               0.291667
# 52        Aaron Wan-Bissaka  0.03               0.058824
# 54          Marcus Rashford  0.29               0.297297
# 59          Scott McTominay  0.09               0.125000
# 61          Mason Greenwood  0.37               0.225806
# 66             Daniel James  0.23               0.200000
# 82   Trent Alexander-Arnold  0.08               0.055556
# ...

# %%
Bra[Bra["Name"]=="Thiago Silva"]

# %%
xg[xg["Name"]=="Joe Willock"]
# Out:
#             Name    xG  Actual_Goals_Per_Game
# 307  Joe Willock  0.33               0.571429

# %%
xg[xg["Name"]=="Tammy Abraham"]
# Out:
#              Name    xG  Actual_Goals_Per_Game
# 16  Tammy Abraham  0.56               0.272727
