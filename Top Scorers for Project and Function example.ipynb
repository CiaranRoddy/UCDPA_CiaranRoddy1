# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("EPL_20_21.csv")

# %%
# slicing to view goals


df.loc[:,"Name":"Goals"]
# Out:
#                   Name              Club Nationality Position  Age  Matches  \
# 0          Mason Mount           Chelsea         ENG    MF,FW   21       36
# 1        Edouard Mendy           Chelsea         SEN       GK   28       31
# 2          Timo Werner           Chelsea         GER       FW   24       35
# 3         Ben Chilwell           Chelsea         ENG       DF   23       27
# 4          Reece James           Chelsea         ENG       DF   20       32
# ..                 ...               ...         ...      ...  ...      ...
# 527        Lys Mousset  Sheffield United         FRA    FW,MF   24       11
# 528     Jack O'Connell  Sheffield United         ENG       DF   26        2
# 529      Iliman Ndiaye  Sheffield United         FRA       MF   21        1
# 530  Antwoine Hackford  Sheffield United         ENG    DF,FW   16        1
# 531        Femi Seriki  Sheffield United         ENG       DF   17        1
#
#      Starts  Mins  Goals
# 0        32  2890      6
# ...

# %%
# getting the data for player who have 15 or more goals 


g=df[df.Goals > 15]

# %%
g
# Out:
#                       Name               Club Nationality Position  Age  \
# 51         Bruno Fernandes  Manchester United         POR       MF   25
# 81           Mohamed Salah       Liverpool FC         EGY       FW   28
# 161          Son Heung-min  Tottenham Hotspur         KOR       FW   28
# 162             Harry Kane  Tottenham Hotspur         ENG       FW   27
# 214        Patrick Bamford       Leeds United         ENG       FW   26
# 237  Dominic Calvert-Lewin            Everton         ENG       FW   23
#
#      Matches  Starts  Mins  Goals  Assists  Passes_Attempted  \
# 51        37      35  3099     18       12              2283
# 81        37      34  3078     22        5              1288
# 161       37      36  3114     17       10              1199
# 162       35      35  3082     23       14               937
# 214       38      37  3050     17        7               506
# 237       33      32  2871     16        0               669
#
# ...

# %%
# displaying them in ascending order


ng=g.loc[:,["Name","Goals"]]
ngg=ng.sort_values(by="Goals",ascending=False)

# %%
ngg
# Out:
#                       Name  Goals
# 162             Harry Kane     23
# 81           Mohamed Salah     22
# 51         Bruno Fernandes     18
# 161          Son Heung-min     17
# 214        Patrick Bamford     17
# 237  Dominic Calvert-Lewin     16

# %%
# graph to illustrate the League's top scorers


x=ngg["Name"]
y=ngg["Goals"]


        
plt.bar(x,y, width=0.9,color = ["honeydew","red","tomato","violet","yellow","dodgerblue"],edgecolor = 'black')
plt.xlabel("Players")
plt.ylabel("Goals")
plt.title("Premier League top scorers")
plt.xticks(rotation=75)
plt.show()

# %%
z =df["Club"]

def fun(x):
    for i in range (len(x)):
        print(x, "played in the premier league")

# %%
fun(z)
# Out:
# 0               Chelsea
# 1               Chelsea
# 2               Chelsea
# 3               Chelsea
# 4               Chelsea
#              ...
# 527    Sheffield United
# 528    Sheffield United
# 529    Sheffield United
# 530    Sheffield United
# 531    Sheffield United
# Name: Club, Length: 532, dtype: object played in the premier league
# 0               Chelsea
# 1               Chelsea
# 2               Chelsea
# 3               Chelsea
# 4               Chelsea
#              ...
# 527    Sheffield United
# 528    Sheffield United
# 529    Sheffield United
# 530    Sheffield United
# 531    Sheffield United
# Name: Club, Length: 532, dtype: object played in the premier league
# 0               Chelsea
# 1               Chelsea
# 2               Chelsea
# 3               Chelsea
# 4               Chelsea
#              ...
# 527    Sheffield United
# 528    Sheffield United
# 529    Sheffield United
# 530    Sheffield United
# 531    Sheffield United
# ...
